# %% [markdown]
# <a href="https://colab.research.google.com/github/bhagyasree2004/statistical_Analysis_RLanguage_Day_1/blob/main/Statistical_analysis_using_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Statistical Analysis using R

# Dataset
data <- c(10,20,30,40,50,60,70)
print("Dataset:")
print(data)


#Mean
mean_value <-mean(data)
print(paste("Mean=",mean_value))

#Medain
median_value <- median(data)
print(paste("Median=",median_value))

#Mode
mode_function<-function(x) {
    uniq_values<-unique(x)
    uniq_values[which.max(tabulate(match(x,uniq_values)))]
}
mode_value <-mode_function(data)
print(paste("Mode=",mode_value))


#max value

max_value<-max(data)
print(paste("Maximum=",max_value))


#min value
min_value<-min(data)
print(paste("Minumum=",min_value))

#variance
variance_value<-var(data)
print(paste("Variance=",variance_value))

#standard deviation
sd_value<-sd(data)
print(paste("standard Deviation=",sd_value))


barplot(data)
pie(data)
hist(data)
plot(data)
boxplot(data)
# Out:
# [1] "Dataset:"
# [1] 10 20 30 40 50 60 70
# [1] "Mean= 40"
# [1] "Median= 40"
# [1] "Mode= 10"
# [1] "Maximum= 70"
# [1] "Minumum= 10"
# [1] "Variance= 466.666666666667"
# [1] "standard Deviation= 21.6024689946929"
# plot without title
# plot without title
# Plot with title “Histogram of data”
# plot without title
# plot without title
